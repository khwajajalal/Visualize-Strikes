# %%
import numpy as np
import pandas as pd

# %%
strikes = pd.read_csv('AfghanistanUSAFdata_ weapons released.csv', skiprows=2)
strikes.columns = strikes.iloc[0]
#strikes = strikes.rename(columns={'nan': 'year'})
strikes = strikes.drop(0)

# %%
strikes.fillna(0)
# Out:
# 0     NaN January February March April  May June July August September  \
# 1  2010.0     156      154   175   197  300  457  325    416       739
# 2  2011.0     405      341   337   339  426  610  695    516       597
# 3  2012.0     170      116   227   252  406  521  504    589       385
# 4  2013.0     193      297   250   284  368  337  256    158       232
# 5  2014.0      92      114    95   115  164  272  205    437       441
# 6  2015.0      40       30    47    31   41  109   79    156       111
# 7  2016.0     127      115    58    62   89   94  160    108       162
# 8  2017.0      54      200   203   460  328  389  350    503       414
# 9  2018.0     378      469   396   562  591  572  746    715       841
#
# 0 October November December Total  \
# 1   1,043      866      272  5100
# 2     663      308      174  5411
# 3     414      297      202  4083
# 4     189      118       76  2758
# 5     217       87      126  2365
# 6     203       69       31   947
# ...

# %%
strikes.rename(columns={nan:'year'}, inplace=True)
#strikes = strikes.rename(index = 1, columns={'1' :'2010',
#                                        '2' :'2011',
#                                        '3' :'2012',
##                                        '4' :'2013',
#                                        '5' :'2014',
#                                        '6' :'2015',
#                                        '7' :'2016',
#                                        '8' :'2017',
#                                        '9' :'2018'} )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-2c1139c59272> in <module>
# ----> 1 strikes.rename(columns={nan:'year'}, inplace=True)
#       2 #strikes = strikes.rename(index = 1, columns={'1' :'2010',
#       3 #                                        '2' :'2011',
#       4 #                                        '3' :'2012',
#       5 ##                                        '4' :'2013',
#
# NameError: name 'nan' is not defined

# %%
strikes = strikes.rename(columns = {np.nan: 'year'})
strikes.columns = strikes.columns.fillna('year')

# %%
strikes
# Out:
# 0    year January February March April  May June July August September  \
# 1  2010.0     156      154   175   197  300  457  325    416       739
# 2  2011.0     405      341   337   339  426  610  695    516       597
# 3  2012.0     170      116   227   252  406  521  504    589       385
# 4  2013.0     193      297   250   284  368  337  256    158       232
# 5  2014.0      92      114    95   115  164  272  205    437       441
# 6  2015.0      40       30    47    31   41  109   79    156       111
# 7  2016.0     127      115    58    62   89   94  160    108       162
# 8  2017.0      54      200   203   460  328  389  350    503       414
# 9  2018.0     378      469   396   562  591  572  746    715       841
#
# 0 October November December Total  \
# 1   1,043      866      272  5100
# 2     663      308      174  5411
# 3     414      297      202  4083
# 4     189      118       76  2758
# 5     217       87      126  2365
# 6     203       69       31   947
# ...

# %%
strikes.to_csv('weaponsReleasedCleaned.csv', index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-7362dfabdb4d> in <module>
#       5 p.yaxis.axis_label = 'Total Munitions'
#       6
# ----> 7 p.line(df.year, df.Total,line_color="purple", line_width = 3)
#       8 p.select_one(HoverTool).tooltips = [
#       9     ('year', '@x'),
#
# ~\Anaconda3\envs\dronestrikes\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'year'
